# %%
import os

# %%
os.getcwd()
# Out:
# 'e:\\projects\\DL_kidney_tumor_pred\\kidney_tumor_prediction_project\\research'

# %%
# 1) Data ingestion


# 2) prapare base model (CNN)-transfer learning - VGG19


# 3) model training


# 4) model evaluation


# 5) deployement/mlflow

# %%
# steps
# 1) update config.yaml
# 2) update params.yaml
# 3) update entity
# 4) update configurataion manager
# 5) update components
# 6) pipeline
# 7) main.py

# %%
# MLFLOW Concept : use to tracking ml models 
# Training and comparing ml evaluations 
# We are using Dogshub for ml flow concepts

# %%
# Save this file
